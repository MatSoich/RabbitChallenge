# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
# sys.path.append('/content/drive/My Drive/DNN_code')
sys.path.append('../')

# %% [markdown]
# # batch normalization

# %%
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet
from common import optimizer

# バッチ正則化 layer
class BatchNormalization:
    '''
    gamma: スケール係数
    beta: オフセット
    momentum: 慣性
    running_mean: テスト時に使用する平均
    running_var: テスト時に使用する分散
    '''
    def __init__(self, gamma, beta, momentum=0.9, running_mean=None, running_var=None):
        self.gamma = gamma
        self.beta = beta
        self.momentum = momentum
        self.input_shape = None

        self.running_mean = running_mean
        self.running_var = running_var  
        
        # backward時に使用する中間データ
        self.batch_size = None
        self.xc = None
        self.std = None
        self.dgamma = None
        self.dbeta = None

    def forward(self, x, train_flg=True):
        if self.running_mean is None:
            N, D = x.shape
            self.running_mean = np.zeros(D)
            self.running_var = np.zeros(D)
                        
        if train_flg:
            mu = x.mean(axis=0) # 平均
            xc = x - mu # xをセンタリング
            var = np.mean(xc**2, axis=0) # 分散
            std = np.sqrt(var + 10e-7) # スケーリング
            xn = xc / std
            
            self.batch_size = x.shape[0]
            self.xc = xc
            self.xn = xn
            self.std = std
            self.running_mean = self.momentum * self.running_mean + (1-self.momentum) * mu # 平均値の加重平均
            self.running_var = self.momentum * self.running_var + (1-self.momentum) * var #分散値の加重平均
        else:
            xc = x - self.running_mean
            xn = xc / ((np.sqrt(self.running_var + 10e-7)))
            
        out = self.gamma * xn + self.beta 
        
        return out

    def backward(self, dout):
        dbeta = dout.sum(axis=0)
        dgamma = np.sum(self.xn * dout, axis=0)
        dxn = self.gamma * dout
        dxc = dxn / self.std
        dstd = -np.sum((dxn * self.xc) / (self.std * self.std), axis=0)
        dvar = 0.5 * dstd / self.std
        dxc += (2.0 / self.batch_size) * self.xc * dvar
        dmu = np.sum(dxc, axis=0)
        dx = dxc - dmu / self.batch_size
        
        self.dgamma = dgamma
        self.dbeta = dbeta

        return dx

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
                        activation='sigmoid', weight_init_std='Xavier', use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.18
#                 : 10. 正答率(テスト) = 0.1208
# Generation: 20. 正答率(トレーニング) = 0.18
#                 : 20. 正答率(テスト) = 0.1557
# Generation: 30. 正答率(トレーニング) = 0.13
#                 : 30. 正答率(テスト) = 0.1805
# Generation: 40. 正答率(トレーニング) = 0.28
#                 : 40. 正答率(テスト) = 0.2204
# Generation: 50. 正答率(トレーニング) = 0.27
#                 : 50. 正答率(テスト) = 0.2555
# Generation: 60. 正答率(トレーニング) = 0.31
#                 : 60. 正答率(テスト) = 0.2842
# Generation: 70. 正答率(トレーニング) = 0.31
#                 : 70. 正答率(テスト) = 0.3139
# Generation: 80. 正答率(トレーニング) = 0.4
#                 : 80. 正答率(テスト) = 0.3575
# Generation: 90. 正答率(トレーニング) = 0.33
#                 : 90. 正答率(テスト) = 0.4264
# Generation: 100. 正答率(トレーニング) = 0.44
#                 : 100. 正答率(テスト) = 0.4574
# Generation: 110. 正答率(トレーニング) = 0.46
#                 : 110. 正答率(テスト) = 0.4929
# Generation: 120. 正答率(トレーニング) = 0.5
#                 : 120. 正答率(テスト) = 0.5135
# Generation: 130. 正答率(トレーニング) = 0.43
#                 : 130. 正答率(テスト) = 0.5306
# Generation: 140. 正答率(トレーニング) = 0.5
#                 : 140. 正答率(テスト) = 0.5426
# Generation: 150. 正答率(トレーニング) = 0.48
#                 : 150. 正答率(テスト) = 0.5554
# Generation: 160. 正答率(トレーニング) = 0.6
#                 : 160. 正答率(テスト) = 0.5695
# Generation: 170. 正答率(トレーニング) = 0.64
#                 : 170. 正答率(テスト) = 0.5819
# Generation: 180. 正答率(トレーニング) = 0.5
#                 : 180. 正答率(テスト) = 0.5914
# Generation: 190. 正答率(トレーニング) = 0.5
#                 : 190. 正答率(テスト) = 0.602
# Generation: 200. 正答率(トレーニング) = 0.55
#                 : 200. 正答率(テスト) = 0.6081
# Generation: 210. 正答率(トレーニング) = 0.61
#                 : 210. 正答率(テスト) = 0.6192
# Generation: 220. 正答率(トレーニング) = 0.64
#                 : 220. 正答率(テスト) = 0.631
# Generation: 230. 正答率(トレーニング) = 0.64
#                 : 230. 正答率(テスト) = 0.6429
# Generation: 240. 正答率(トレーニング) = 0.61
#                 : 240. 正答率(テスト) = 0.6468
# Generation: 250. 正答率(トレーニング) = 0.58
#                 : 250. 正答率(テスト) = 0.656
# Generation: 260. 正答率(トレーニング) = 0.72
#                 : 260. 正答率(テスト) = 0.6583
# Generation: 270. 正答率(トレーニング) = 0.7
#                 : 270. 正答率(テスト) = 0.6601
# Generation: 280. 正答率(トレーニング) = 0.62
#                 : 280. 正答率(テスト) = 0.6671
# Generation: 290. 正答率(トレーニング) = 0.69
#                 : 290. 正答率(テスト) = 0.668
# Generation: 300. 正答率(トレーニング) = 0.7
#                 : 300. 正答率(テスト) = 0.6725
# Generation: 310. 正答率(トレーニング) = 0.68
#                 : 310. 正答率(テスト) = 0.678
# Generation: 320. 正答率(トレーニング) = 0.65
#                 : 320. 正答率(テスト) = 0.6783
# Generation: 330. 正答率(トレーニング) = 0.66
#                 : 330. 正答率(テスト) = 0.6805
# Generation: 340. 正答率(トレーニング) = 0.64
#                 : 340. 正答率(テスト) = 0.6809
# Generation: 350. 正答率(トレーニング) = 0.73
#                 : 350. 正答率(テスト) = 0.688
# Generation: 360. 正答率(トレーニング) = 0.66
#                 : 360. 正答率(テスト) = 0.694
# Generation: 370. 正答率(トレーニング) = 0.63
#                 : 370. 正答率(テスト) = 0.6998
# Generation: 380. 正答率(トレーニング) = 0.74
#                 : 380. 正答率(テスト) = 0.7031
# Generation: 390. 正答率(トレーニング) = 0.66
#                 : 390. 正答率(テスト) = 0.7094
# Generation: 400. 正答率(トレーニング) = 0.71
#                 : 400. 正答率(テスト) = 0.711
# Generation: 410. 正答率(トレーニング) = 0.65
#                 : 410. 正答率(テスト) = 0.7135
# Generation: 420. 正答率(トレーニング) = 0.69
#                 : 420. 正答率(テスト) = 0.7224
# Generation: 430. 正答率(トレーニング) = 0.75
#                 : 430. 正答率(テスト) = 0.7226
# Generation: 440. 正答率(トレーニング) = 0.68
#                 : 440. 正答率(テスト) = 0.7239
# Generation: 450. 正答率(トレーニング) = 0.69
#                 : 450. 正答率(テスト) = 0.7246
# Generation: 460. 正答率(トレーニング) = 0.62
#                 : 460. 正答率(テスト) = 0.7292
# Generation: 470. 正答率(トレーニング) = 0.7
#                 : 470. 正答率(テスト) = 0.7375
# Generation: 480. 正答率(トレーニング) = 0.69
#                 : 480. 正答率(テスト) = 0.7404
# Generation: 490. 正答率(トレーニング) = 0.81
#                 : 490. 正答率(テスト) = 0.7433
# Generation: 500. 正答率(トレーニング) = 0.77
#                 : 500. 正答率(テスト) = 0.7428
# Generation: 510. 正答率(トレーニング) = 0.73
#                 : 510. 正答率(テスト) = 0.7423
# Generation: 520. 正答率(トレーニング) = 0.73
#                 : 520. 正答率(テスト) = 0.7462
# Generation: 530. 正答率(トレーニング) = 0.76
#                 : 530. 正答率(テスト) = 0.7494
# Generation: 540. 正答率(トレーニング) = 0.73
#                 : 540. 正答率(テスト) = 0.7459
# Generation: 550. 正答率(トレーニング) = 0.76
#                 : 550. 正答率(テスト) = 0.7492
# Generation: 560. 正答率(トレーニング) = 0.72
#                 : 560. 正答率(テスト) = 0.7528
# Generation: 570. 正答率(トレーニング) = 0.72
#                 : 570. 正答率(テスト) = 0.7575
# Generation: 580. 正答率(トレーニング) = 0.77
#                 : 580. 正答率(テスト) = 0.7571
# Generation: 590. 正答率(トレーニング) = 0.77
#                 : 590. 正答率(テスト) = 0.7584
# Generation: 600. 正答率(トレーニング) = 0.69
#                 : 600. 正答率(テスト) = 0.7622
# Generation: 610. 正答率(トレーニング) = 0.73
#                 : 610. 正答率(テスト) = 0.7619
# Generation: 620. 正答率(トレーニング) = 0.74
#                 : 620. 正答率(テスト) = 0.766
# Generation: 630. 正答率(トレーニング) = 0.78
#                 : 630. 正答率(テスト) = 0.7691
# Generation: 640. 正答率(トレーニング) = 0.73
#                 : 640. 正答率(テスト) = 0.7681
# Generation: 650. 正答率(トレーニング) = 0.78
#                 : 650. 正答率(テスト) = 0.7712
# Generation: 660. 正答率(トレーニング) = 0.79
#                 : 660. 正答率(テスト) = 0.7725
# Generation: 670. 正答率(トレーニング) = 0.83
#                 : 670. 正答率(テスト) = 0.7739
# Generation: 680. 正答率(トレーニング) = 0.7
#                 : 680. 正答率(テスト) = 0.7754
# Generation: 690. 正答率(トレーニング) = 0.83
#                 : 690. 正答率(テスト) = 0.7734
# Generation: 700. 正答率(トレーニング) = 0.79
#                 : 700. 正答率(テスト) = 0.7737
# Generation: 710. 正答率(トレーニング) = 0.76
#                 : 710. 正答率(テスト) = 0.7758
# Generation: 720. 正答率(トレーニング) = 0.78
#                 : 720. 正答率(テスト) = 0.7788
# Generation: 730. 正答率(トレーニング) = 0.78
#                 : 730. 正答率(テスト) = 0.7752
# Generation: 740. 正答率(トレーニング) = 0.84
#                 : 740. 正答率(テスト) = 0.7814
# Generation: 750. 正答率(トレーニング) = 0.78
#                 : 750. 正答率(テスト) = 0.7827
# Generation: 760. 正答率(トレーニング) = 0.8
#                 : 760. 正答率(テスト) = 0.784
# Generation: 770. 正答率(トレーニング) = 0.79
#                 : 770. 正答率(テスト) = 0.7886
# Generation: 780. 正答率(トレーニング) = 0.77
#                 : 780. 正答率(テスト) = 0.788
# Generation: 790. 正答率(トレーニング) = 0.82
#                 : 790. 正答率(テスト) = 0.7903
# Generation: 800. 正答率(トレーニング) = 0.86
#                 : 800. 正答率(テスト) = 0.7929
# Generation: 810. 正答率(トレーニング) = 0.79
#                 : 810. 正答率(テスト) = 0.7938
# Generation: 820. 正答率(トレーニング) = 0.77
#                 : 820. 正答率(テスト) = 0.794
# Generation: 830. 正答率(トレーニング) = 0.84
#                 : 830. 正答率(テスト) = 0.7934
# Generation: 840. 正答率(トレーニング) = 0.84
#                 : 840. 正答率(テスト) = 0.7952
# Generation: 850. 正答率(トレーニング) = 0.85
#                 : 850. 正答率(テスト) = 0.7961
# Generation: 860. 正答率(トレーニング) = 0.8
#                 : 860. 正答率(テスト) = 0.8001
# Generation: 870. 正答率(トレーニング) = 0.78
#                 : 870. 正答率(テスト) = 0.8018
# Generation: 880. 正答率(トレーニング) = 0.73
#                 : 880. 正答率(テスト) = 0.8017
# Generation: 890. 正答率(トレーニング) = 0.81
#                 : 890. 正答率(テスト) = 0.8016
# Generation: 900. 正答率(トレーニング) = 0.82
#                 : 900. 正答率(テスト) = 0.8007
# Generation: 910. 正答率(トレーニング) = 0.77
#                 : 910. 正答率(テスト) = 0.8033
# Generation: 920. 正答率(トレーニング) = 0.76
#                 : 920. 正答率(テスト) = 0.8027
# Generation: 930. 正答率(トレーニング) = 0.79
#                 : 930. 正答率(テスト) = 0.8006
# Generation: 940. 正答率(トレーニング) = 0.79
#                 : 940. 正答率(テスト) = 0.7976
# Generation: 950. 正答率(トレーニング) = 0.82
#                 : 950. 正答率(テスト) = 0.8003
# Generation: 960. 正答率(トレーニング) = 0.83
#                 : 960. 正答率(テスト) = 0.8006
# Generation: 970. 正答率(トレーニング) = 0.79
#                 : 970. 正答率(テスト) = 0.805
# Generation: 980. 正答率(トレーニング) = 0.76
#                 : 980. 正答率(テスト) = 0.8052
# Generation: 990. 正答率(トレーニング) = 0.84
#                 : 990. 正答率(テスト) = 0.807
# Generation: 1000. 正答率(トレーニング) = 0.68
#                 : 1000. 正答率(テスト) = 0.8063

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] 活性化関数や重みの初期値を変えてみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
